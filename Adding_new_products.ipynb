# %%
import json

fd= open("record.json","r")

r=fd.read()

fd.close()

record= json.loads(r)

# %%
record
# Out:
# {'1000': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'oreo',
#   'price': 10,
#   'quantity': 100},
#  '1001': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'sunfeast',
#   'price': 10,
#   'quantity': 100},
#  '1002': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'gudday',
#   'price': 10,
#   'quantity': 100},
#  '1003': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'bourbon',
#   'price': 10,
#   'quantity': 100},
#  '1004': {'categories': 'chips',
#   'eatable': 'veg',
#   'name': 'lays',
#   'price': 10,
#   'quantity': 100},
#  '1005': {'categories': 'chips',
#   'eatable': 'veg',
#   'name': 'kurkure',
#   'price': 10,
#   'quantity': 100},
#  '1006': {'categories': 'chips',
#   'eatable': 'veg',
#   'name': 'unclechips',
#   'price': 10,
#   'quantity': 100},
#  '1007': {'categories': 'soft drink',
#   'eatable': 'veg',
#   'name': 'mirinda',
#   'price': 30,
#   'quantity': 100},
# ...

# %%
1product_id=str(input("Enter the product id you want to add:"))
name      =str(input("Enter product name:"))
price     =int(input("Enter the price of product:"))
quantity  =int(input("Enter the quantity of product:"))
categories  =str(input("Enter the catergory of product:"))
eatable   =str(input("Enter the eatable of product:"))

record[product_id] ={"name":name,"quantity":quantity,"price":price,"categories":categories,"eatable":eatable}

js= json.dumps(record)

fd= open("record","w")
fd.write(js)
fd.close()
# Out:
# Enter the product id you want to add:1111
# Enter product name:toritos
# Enter the price of product:10
# Enter the quantity of product:10
# Enter the catergory of product:chips
# Enter the eatable of product:veg

# %%
record
# Out:
# {'1000': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'oreo',
#   'price': 10,
#   'quantity': 100},
#  '1001': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'sunfeast',
#   'price': 10,
#   'quantity': 100},
#  '1002': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'gudday',
#   'price': 10,
#   'quantity': 100},
#  '1003': {'categories': 'biscuit',
#   'eatable': 'veg',
#   'name': 'bourbon',
#   'price': 10,
#   'quantity': 100},
#  '1004': {'categories': 'chips',
#   'eatable': 'veg',
#   'name': 'lays',
#   'price': 10,
#   'quantity': 100},
#  '1005': {'categories': 'chips',
#   'eatable': 'veg',
#   'name': 'kurkure',
#   'price': 10,
#   'quantity': 100},
#  '1006': {'categories': 'chips',
#   'eatable': 'veg',
#   'name': 'unclechips',
#   'price': 10,
#   'quantity': 100},
#  '1007': {'categories': 'soft drink',
#   'eatable': 'veg',
#   'name': 'mirinda',
#   'price': 30,
#   'quantity': 100},
# ...
